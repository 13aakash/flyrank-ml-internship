# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/13aakash/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# Lane: Refresh / Content Opportunity Scoring
#
# I chose the Refresh / Content Opportunity Scoring lane because I want to investigate which pages should be reviewed first for refresh, expansion, protection, pruning, or monitoring. This lane connects search and content signals to a practical decision: helping a content or SEO team prioritize limited review time. I already saw in the starter notebooks that a learned ranking can outperform a simple hand-written rule, so this looks like a useful direction to investigate further. I will treat the lane as provisional and refine the question as I learn more from the data.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Selected lane: Refresh / Content Opportunity Scoring")
print("Goal: Rank pages for review using observable content and search-performance signals.")
# Out:
# Selected lane: Refresh / Content Opportunity Scoring
# Goal: Rank pages for review using observable content and search-performance signals.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# **Decision:** Which pages should be reviewed first for a possible content refresh or other action?
#
# **Who acts on it:** An SEO or content team would use the ranking to decide which pages deserve attention first.
#
# **Action:** The team could review the highest-priority pages and decide whether to refresh, expand, protect, prune, or simply monitor them based on the available evidence.
#
# **Cost of a wrong recommendation:** If a page that genuinely needs attention is missed, the team may lose an opportunity to protect or improve its search performance. If a healthy page is incorrectly prioritized, limited team time may be wasted reviewing or changing content that did not need attention.
#
# **Research question:** Can observable content and search-performance signals help rank pages for review so that an SEO or content team can prioritize its limited review effort more effectively?

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
decision = "Which pages should be reviewed first?"
action = "Prioritize pages for refresh, expansion, protection, pruning, or monitoring."
wrong_call_cost = "Wasted review effort or missed opportunities to address pages that need attention."

print("Decision:", decision)
print("Action:", action)
print("Cost of wrong recommendation:", wrong_call_cost)
# Out:
# Decision: Which pages should be reviewed first?
# Action: Prioritize pages for refresh, expansion, protection, pruning, or monitoring.
# Cost of wrong recommendation: Wasted review effort or missed opportunities to address pages that need attention.

# %%
import os
import sys
import subprocess

REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if not os.path.isdir(REPO_DIR):
    subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)

os.chdir(REPO_DIR)

print("Working directory:", os.getcwd())
print("Dataset exists:", os.path.exists("data/raw/content_refresh_anonymized.csv"))
# Out:
# Working directory: /content/flyrank-ml-internship-starter
# Dataset exists: True

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
# The starter dataset contains 30,000 pages and 44 columns, providing a useful set of observable content and search-performance signals to investigate. Of these pages, 16,262 are labeled as declining based on the starter dataset's `trend_direction` field. This makes it worth investigating whether observable signals can help prioritize which pages deserve review, while recognizing that the starter label is only a proxy for the broader refresh decision.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Total pages:", len(df))
print("Total columns:", len(df.columns))
print("Declining pages:", (df["trend_direction"].str.lower() == "down").sum())
# Out:
# Total pages: 30000
# Total columns: 44
# Declining pages: 16262

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# I can identify observed and directional relationships between the available content and search-performance signals and use them to support a ranked review decision. I can also test whether a simple baseline or model provides useful prioritization compared with another method. These results are decision-support, not guarantees.
#
# I cannot claim that a particular signal causes a page's performance to change, that refreshing a page will definitely improve its performance, or that I have discovered or predicted Google's ranking algorithm. The data is observational, so any findings will be described carefully as observed or directional relationships. Any recommendations will still require human review.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
allowed_claims = [
    "Observed relationships between measurable signals",
    "Directional evidence for prioritization",
    "Decision-support recommendations"
]

not_claims = [
    "Causal proof that a refresh will improve performance",
    "Prediction of Google's ranking algorithm"
]

print("What I can claim:")
for item in allowed_claims:
    print("-", item)

print("\nWhat I cannot claim:")
for item in not_claims:
    print("-", item)
# Out:
# What I can claim:
# - Observed relationships between measurable signals
# - Directional evidence for prioritization
# - Decision-support recommendations
#
# What I cannot claim:
# - Causal proof that a refresh will improve performance
# - Prediction of Google's ranking algorithm

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
